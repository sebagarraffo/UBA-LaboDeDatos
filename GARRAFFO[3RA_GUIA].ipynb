# %%
#EJ 1
datosArgentina = gapminder[gapminder["country"]=="Argentina"]
(
so.Plot(data = datosArgentina, x = "year", y = "lifeExp")
 .add(so.Line ())
)

# %%
#!pip install seaborn

# %%
from gapminder import gapminder
import seaborn.objects as so

# %%
#EJ 2 
paisesAmerica = gapminder[gapminder["continent"]== "Americas"]

(
so.Plot(data = paisesAmerica, x = "year", y = "lifeExp", group = "country", color = "country")
.add(so.Line())
)

# %%
#EJ 3

import matplotlib.pyplot as plt

paisesAmerica = gapminder[gapminder["continent"]== "Americas"]
paisesAsia = gapminder[gapminder["continent"]== "Asia"]
paisesAfrica = gapminder[gapminder["continent"]== "Africa"]
paisesEuropa = gapminder[gapminder["continent"]== "Europe"]
paisesOceania = gapminder[gapminder["continent"]== "Oceania"]

(    
so.Plot(data = paisesAmerica, x = "year", y = "lifeExp")
.add(so.Lines(color = "#bbca"), group = "country")
.add(so.Line(), so.PolyFit(1))

)

# %%
#EJ 4 

(
so.Plot (data = gapminder , x = "year", y = "lifeExp")
.add(so.Lines(color = "#bbca"), group = "country")
.add(so.Line(), so.PolyFit(1))
.facet("continent", wrap = 3)
)

# %%
import seaborn as sns
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm
# 0    Adelie  Torgersen            39.1           18.7              181.0  \
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
(
so.Plot (
penguins , x = "bill_length_mm" , y = "bill_depth_mm" ,
edgewidth = "body_mass_g" , marker = "species" ,
linestyle = "island" , color = "species"
)
. add ( so . Dot ( color = ".8" ) , edgecolor = "sex" )
)

# %%
#EJ 5
(
so.Plot (penguins, x = "bill_depth_mm" , y = "bill_length_mm", color = "sex")
.add(so.Dot())
.facet("species", wrap = 2)
)

# %%
#EJ 6
penguins.groupby("island").size()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# dtype: int64

# %%
pinguinos_por_isla = penguins.groupby("island").size()

(
so.Plot (x = pinguinos_por_isla.index , y = pinguinos_por_isla)
.add (so.Bar())
)

# %%
(
so.Plot ( data = penguins , ???)
.add (so.Bar(), so.Hist() )
)
